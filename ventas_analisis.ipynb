# %% [markdown]
# # Análisis de Ventas de Tecnología
#
# Este notebook analiza los datos de ventas de productos tecnológicos durante el año 2023.

# %%
# Importar librerías necesarias
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Cargar datos
# Reemplaza la URL con la de tu archivo raw en GitHub
url = 'https://raw.githubusercontent.com/sterrenm/proyecto_integrado_1/refs/heads/main/ventas_tecnologia%20(2).csv'
df = pd.read_csv(url)
df.head()
# Out:
#      Unnamed: 0 Unnamed: 1   Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5
# 0           Mes    Laptops  Smartphones    Tablets  Auriculares    SmartTV
# 1    Enero 2023         45          120         35           89         12
# 2  Febrero 2023         38          145         42           95         15
# 3    Marzo 2023         52          135         38          102         18
# 4    Abril 2023         49          155         45          115         20

# %%
# Crear gráfico de líneas para todas las categorías
plt.figure(figsize=(15, 8))
for columna in df.columns[1:]:  # Excluimos la columna 'Mes'
    plt.plot(df['Mes'], df[columna], marker='o', label=columna)

plt.title('Ventas de Productos Tecnológicos 2023')
plt.xlabel('Mes')
plt.ylabel('Unidades Vendidas')
plt.xticks(rotation=45)
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Mes'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-2575e577cca0> in <cell line: 3>()
#       2 plt.figure(figsize=(15, 8))
#       3 for columna in df.columns[1:]:  # Excluimos la columna 'Mes'
# ----> 4     plt.plot(df['Mes'], df[columna], marker='o', label=columna)
#       5
#       6 plt.title('Ventas de Productos Tecnológicos 2023')
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    4100             if self.columns.nlevels > 1:
#    4101                 return self._getitem_multilevel(key)
# -> 4102             indexer = self.columns.get_loc(key)
#    4103             if is_integer(indexer):
#    4104                 indexer = [indexer]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3810             ):
#    3811                 raise InvalidIndexError(key)
# -> 3812             raise KeyError(key) from err
#    3813         except TypeError:
#    3814             # If we have a listlike key, _check_indexing_error will raise
#
# KeyError: 'Mes'

# %% [markdown]
# ## Espacio para análisis adicional del alumno
#
# En esta sección puedes agregar tu propio código para análisis adicionales.

# %%
# Tu código aquí

# %%
# prompt: generar datos descriptivos

# Análisis descriptivo de los datos

# Resumen estadístico
print(df.describe())

# Información sobre los tipos de datos y valores faltantes
print(df.info())






# Histograma de las ventas de cada producto
df.hist(figsize=(16, 12), bins=10)
plt.suptitle("Distribución de las ventas por producto")
plt.show()

# Boxplot para identificar valores atípicos
plt.figure(figsize=(10,6))
sns.boxplot(data=df.iloc[:,1:]) #Excluimos la columna 'Mes'
plt.title("Boxplot de las ventas por producto")
plt.xticks(rotation=45)
plt.show()
# Out:
#        Unnamed: 0 Unnamed: 1   Unnamed: 2 Unnamed: 3   Unnamed: 4 Unnamed: 5  \
# count          13         13           13         13           13         13
# unique         13         13           13         13           13         13
# top           Mes    Laptops  Smartphones    Tablets  Auriculares    SmartTV
# freq            1          1            1          1            1          1
#
#                                              Total Ventas
# count                                                  13
# unique                                                 13
# top     MesLaptopsSmartphonesTabletsAuricularesSmartTV...
# freq                                                    1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    13 non-null     object
#  1   Unnamed: 1    13 non-null     object
#  2   Unnamed: 2    13 non-null     object
#  3   Unnamed: 3    13 non-null     object
#  4   Unnamed: 4    13 non-null     object
#  5   Unnamed: 5    13 non-null     object
#  6   Total Ventas  13 non-null     object
# dtypes: object(7)
# memory usage: 856.0+ bytes
# None
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-9d64f0796673> in <cell line: 17>()
#      15
#      16 # Histograma de las ventas de cada producto
# ---> 17 df.hist(figsize=(16, 12), bins=10)
#      18 plt.suptitle("Distribución de las ventas por producto")
#      19 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_core.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, backend, legend, **kwargs)
#     249     """
#     250     plot_backend = _get_plot_backend(backend)
# --> 251     return plot_backend.hist_frame(
#     252         data,
#     253         column=column,
#
# /usr/local/lib/python3.10/dist-packages/pandas/plotting/_matplotlib/hist.py in hist_frame(data, column, by, grid, xlabelsize, xrot, ylabelsize, yrot, ax, sharex, sharey, figsize, layout, bins, legend, **kwds)
#     547
#     548     if naxes == 0:
# --> 549         raise ValueError(
#     550             "hist method requires numerical or datetime columns, nothing to plot."
#     551         )
#
# ValueError: hist method requires numerical or datetime columns, nothing to plot.
